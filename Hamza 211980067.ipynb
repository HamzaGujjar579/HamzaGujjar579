# %% [markdown]
# import Csv file using pandas

# %%
import pandas as pd
df = pd.read_csv("DataSet.csv")
df
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 0     2951110000999929511        92             238  Not Delivered
# 1     2181910000999921819        61             136  Not Delivered
# 2     3239110000999932391        67             235  Not Delivered
# 3     1112610000999911126        33             133    Not Shipped
# 4     1548310000999915483        13             189  Not Delivered
# ...                   ...       ...             ...            ...
# 9994  2301610000999923016        75             201  Not Delivered
# 9995  1847410000999918474        37             135        Shipped
# 9996  2385710000999923857        81             207      Delivered
# 9997  2281610000999922816        18             117        Shipped
# 9998  1468010000999914680        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0     2021-08-08       Healthcare         Pablo                  21
# ...

# %% [markdown]
# ## head()
# ##### This function helps you to get the first few rows of the dataset. By default, it returns the first 5 rows.
# ##### However, you can change this number by simply mentioning the desired number of rows
# ###### in df.head()

# %%
df.head(101)
# Out:
#                  OrderID  Quantity  UnitPrice(USD)         Status   OrderDate  \
# 0    2951110000999929511        92             238  Not Delivered  2021-08-08
# 1    2181910000999921819        61             136  Not Delivered  2021-10-03
# 2    3239110000999932391        67             235  Not Delivered  2021-09-27
# 3    1112610000999911126        33             133    Not Shipped  2021-07-30
# 4    1548310000999915483        13             189  Not Delivered  2021-08-15
# ..                   ...       ...             ...            ...         ...
# 96   3070510000999930705        60             120  Not Delivered  2021-08-03
# 97   3008110000999930081        81             226        Shipped  2021-07-15
# 98   3059610000999930596        35             167    Not Shipped  2021-11-25
# 99   3206210000999932062        19             197      Delivered  2021-09-10
# 100  4040610000999940406        93             197  Not Delivered  2021-09-07
#
# ...

# %% [markdown]
# ## df.tail()
# ##### This function helps you to get the last few rows of the dataset. By default, it returns the last
# ###### 5 rows, and similar to .head(), you can simply mention the desired number of rows
# ###### in df.tail()

# %%
df.tail()
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 9994  2301610000999923016        75             201  Not Delivered
# 9995  1847410000999918474        37             135        Shipped
# 9996  2385710000999923857        81             207      Delivered
# 9997  2281610000999922816        18             117        Shipped
# 9998  1468010000999914680        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 9994  2021-10-16             Home         Sofia                  20
# 9995  2021-10-03       Healthcare         Maria                  30
# 9996  2021-11-13           Office          Emma                  29
# 9997  2021-12-23          Fashion        Stella                  22
# 9998  2021-07-12    Entertainment       Anthony                  25
#
#       Delivery_Time(Days) Shipping_Address Product_Code  OrderCode
# 9994                 14.0            Kenya        H-555     444885
# ...

# %% [markdown]
# ## df.sample(9)
# ###### This function is used to get a randomly selected row, column, or both from a dataset.
# ###### df.sample() takes 7 optional parameters, which means this function can be run without using
# ######  any argument as below.

# %%
df.sample(9)
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 5900  3236710000999932367        26             143      Delivered
# 4336  3452310000999934523       100             154        Shipped
# 4688  2569710000999925697        53             203      Delivered
# 206   1577810000999915778        82             126    Not Shipped
# 137   2414210000999924142        65             158    Not Shipped
# 3673  1727910000999917279        36             238  Not Delivered
# 752   3489910000999934899        81             169  Not Delivered
# 779   3382310000999933823        93             207    Not Shipped
# 3872  1198010000999911980         3             120    Not Shipped
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 5900  2021-09-21    Entertainment          John                  21
# 4336  2021-07-17    Entertainment          John                  28
# 4688  2021-08-24    Entertainment         Sofia                  21
# ...

# %% [markdown]
# ## df.info()
# ###### This function returns a quick summary of the DataFrame. This includes information about
# ######  column names and their respective data types, missing values, and memory consumption
# ######  by DataFrame, as shown below.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   OrderID              9999 non-null   int64
#  1   Quantity             9999 non-null   int64
#  2   UnitPrice(USD)       9999 non-null   int64
#  3   Status               9999 non-null   object
#  4   OrderDate            9999 non-null   object
#  5   Product_Category     9963 non-null   object
#  6   Sales_Manager        9999 non-null   object
#  7   Shipping_Cost(USD)   9999 non-null   int64
#  8   Delivery_Time(Days)  9948 non-null   float64
#  9   Shipping_Address     9999 non-null   object
#  10  Product_Code         9999 non-null   object
#  11  OrderCode            9999 non-null   int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 937.5+ KB

# %% [markdown]
# ## df.describe()
# ###### This function returns descriptive statistics about the data. This includes minimum,
# ######  maximum, mean (central tendency), standard deviation (dispersion) of the values in
# ######  numerical columns, and the count of all non-null values in the data, as shown below.
# ######  df.describe()

# %% [markdown]
# df.describe()

# %% [markdown]
# ## df.query()
# ###### This function is used to query the DataFrame based on an expression. An expression can
# ######  be as simple as a single condition and as complex as a combination of multiple conditions.

# %%
df.query("Quantities > 92")
# Out:
#                   OrderID  Quantities  UnitPrice(USD)         Status  \
# 9450  2502610000999925026         100             236    Not Shipped
# 2719  2829410000999928294         100             117    Not Shipped
# 6755  3107210000999931072         100             185    Not Shipped
# 9164  3821310000999938213         100             101    Not Shipped
# 4083  1490310000999914903         100             170        Shipped
# ...                   ...         ...             ...            ...
# 3942  3065410000999930654          93             119  Not Delivered
# 2030  1311410000999913114          93             198        Shipped
# 7760  2456610000999924566          93             182      Delivered
# 3837  2613710000999926137          93             119  Not Delivered
# 2088  3224810000999932248          93             239    Not Shipped
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 9450  2021-09-07       Healthcare         Abdul                  24
# ...

# %% [markdown]
# ## df.loc()
# ###### This function is a property of DataFrame that returns the group of rows and columns
# ######  identified by their labels or names.

# %%
df.loc[100,"Sales_Manager"]
# Out:
# 'John'

# %% [markdown]
# ## df.unique()
# ###### This function returns the list of unique values in a column or series. Instead of applying on
# ###### complete DataFrame, it works only on the selected single column.

# %%
df["Sales_Manager"].unique()
# Out:
# array(['Pablo', 'Kristen', 'Abdul', 'Stella', 'Emma', 'John', 'Jacob',
#        'Sofia', 'Maria', 'Anthony'], dtype=object)

# %% [markdown]
# ## df.nunique()
# ##### The nunique() method returns the number of unique values for each column. By specifying the column axis ( axis='columns' ), the nunique() method searches column-wise and returns the number of unique values for each row.

# %%
df["Quantity"].nunique()
# Out:
# 100

# %% [markdown]
# ## df.isnull()
# ##### The isnull() method returns a DataFrame object where all the values are replaced with a Boolean value True for NULL values, and otherwise False.

# %%
df["Sales_Manager"].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9994    False
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# Name: Sales_Manager, Length: 9999, dtype: bool

# %% [markdown]
# ## df.fillna()
# ##### The fillna() method replaces the NULL values with a specified value. The fillna() method returns a new DataFrame object unless the inplace parameter is set to True , in that case the fillna() method does the replacing in the original DataFrame instead.

# %%
df2 = df.fillna("none")
print(df2)
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 0     2951110000999929511        92             238  Not Delivered
# 1     2181910000999921819        61             136  Not Delivered
# 2     3239110000999932391        67             235  Not Delivered
# 3     1112610000999911126        33             133    Not Shipped
# 4     1548310000999915483        13             189  Not Delivered
# ...                   ...       ...             ...            ...
# 9994  2301610000999923016        75             201  Not Delivered
# 9995  1847410000999918474        37             135        Shipped
# 9996  2385710000999923857        81             207      Delivered
# 9997  2281610000999922816        18             117        Shipped
# 9998  1468010000999914680        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0     2021-08-08       Healthcare         Pablo                  21
# ...

# %% [markdown]
# ## df.sort_values()
# ##### Pandas sort_values() function sorts a data frame in Ascending or Descending order of passed Column

# %%
df.sort_values(by = "Quantity" ,ascending=False , inplace=False)
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 9450  2502610000999925026       100             236    Not Shipped
# 6075  1649410000999916494       100             149  Not Delivered
# 5848  4016510000999940165       100             189        Shipped
# 3245  4907310000999949073       100             171  Not Delivered
# 1350  2321510000999923215       100             117      Delivered
# ...                   ...       ...             ...            ...
# 8818  1106110000999911061         1             167      Delivered
# 2314  3552710000999935527         1             117      Delivered
# 2643  4662110000999946621         1             180        Shipped
# 1255  1054210000999910542         1             171        Shipped
# 1739  2120410000999921204         1             163    Not Shipped
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 9450  2021-09-07       Healthcare         Abdul                  24
# ...

# %% [markdown]
# ## df.value_counts()
# ##### When you use value_counts on a dataframe, it will count the number of records for every combination of unique values for every column.

# %%
df["Quantity"].value_counts()
# Out:
# 50    127
# 15    119
# 52    118
# 95    118
# 94    117
#      ...
# 72     85
# 12     81
# 36     81
# 64     80
# 40     79
# Name: Quantity, Length: 100, dtype: int64

# %% [markdown]
# ## df.nlargest()
# ##### Pandas nlargest() method is used to get n largest values from a data frame or a series.

# %%
df.nlargest(10,"Quantity")
# Out:
#                  OrderID  Quantity  UnitPrice(USD)         Status   OrderDate  \
# 25   3063710000999930637       100             173  Not Delivered  2021-12-22
# 54   4861510000999948615       100             237        Shipped  2021-10-03
# 185  2768610000999927686       100             241    Not Shipped  2021-12-18
# 417  1015510000999910155       100             154  Not Delivered  2021-07-31
# 503  2085610000999920856       100             108  Not Delivered  2021-12-24
# 551  3442310000999934423       100             218  Not Delivered  2021-09-16
# 624  1502710000999915027       100             193  Not Delivered  2021-12-14
# 714  1999110000999919991       100             240    Not Shipped  2021-10-20
# 920  3901110000999939011       100             206  Not Delivered  2021-07-31
# 969  4897610000999948976       100             233        Shipped  2021-08-11
#
#     Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# ...

# %% [markdown]
# ## df.nsmallest()
# ##### The nsmallest() function is used to get the first n rows ordered by columns in ascending order. This method is equivalent to df. sort_values(columns, ascending=True). head(n), but more performant.

# %%
df.nsmallest(10,"Quantity")
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 4147  3534810000999935348         1             191    Not Shipped
# 5137  4305210000999943052         1             119  Not Delivered
# 3878  4712310000999947123         1             173        Shipped
# 6103  4009310000999940093         1             197      Delivered
# 8530  1348910000999913489         1             188        Shipped
# 3920  2845810000999928458         1             245  Not Delivered
# 609   2695810000999926958         1             199      Delivered
# 3347  2617410000999926174         1             177  Not Delivered
# 8658  1261610000999912616         1             121  Not Delivered
# 7526  1202110000999912021         1             114      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 4147  2021-10-09          Fashion         Pablo                  28
# 5137  2021-07-16    Entertainment         Jacob                  30
# ...

# %% [markdown]
# ## df.copy()
# ##### The copy() method returns a copy of the DataFrame.
#
# ##### By default, the copy is a "deep copy" meaning that any changes made in the original DataFrame will NOT be reflected in the copy.

# %%
df2 = df.copy()
df2
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 9450  2502610000999925026       100             236    Not Shipped
# 2719  2829410000999928294       100             117    Not Shipped
# 6755  3107210000999931072       100             185    Not Shipped
# 9164  3821310000999938213       100             101    Not Shipped
# 4083  1490310000999914903       100             170        Shipped
# ...                   ...       ...             ...            ...
# 5952  2228310000999922283         1             203  Not Delivered
# 6918  3018210000999930182         1             250    Not Shipped
# 5337  1037610000999910376         1             185      Delivered
# 8242  3263410000999932634         1             130      Delivered
# 1739  2120410000999921204         1             163    Not Shipped
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 9450  2021-09-07       Healthcare         Abdul                  24
# ...

# %% [markdown]
# ## df.rename()
# ##### The rename() method allows you to change the row indexes, and the columns labels.

# %%
df.rename({"0" : "10"} ,axis=0)
df
# Out:
#                   OrderID  Quantities  UnitPrice(USD)         Status  \
# 0     2951110000999929511          92             238  Not Delivered
# 1     2181910000999921819          61             136  Not Delivered
# 2     3239110000999932391          67             235  Not Delivered
# 3     1112610000999911126          33             133    Not Shipped
# 4     1548310000999915483          13             189  Not Delivered
# ...                   ...         ...             ...            ...
# 9994  2301610000999923016          75             201  Not Delivered
# 9995  1847410000999918474          37             135        Shipped
# 9996  2385710000999923857          81             207      Delivered
# 9997  2281610000999922816          18             117        Shipped
# 9998  1468010000999914680          53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0     2021-08-08       Healthcare         Pablo                  21
# ...

# %% [markdown]
# ## df.where()
# ##### DataFrame. where() function is similar to if-then/if else that is used to check the one or multiple conditions of an expression in DataFrame and replace with another value when the condition becomes False.

# %%
df.where(df["Quantities"] > 92)

df
# Out:
#                   OrderID  Quantities  UnitPrice(USD)         Status  \
# 9450  2502610000999925026         100             236    Not Shipped
# 2719  2829410000999928294         100             117    Not Shipped
# 6755  3107210000999931072         100             185    Not Shipped
# 9164  3821310000999938213         100             101    Not Shipped
# 4083  1490310000999914903         100             170        Shipped
# ...                   ...         ...             ...            ...
# 5952  2228310000999922283           1             203  Not Delivered
# 6918  3018210000999930182           1             250    Not Shipped
# 5337  1037610000999910376           1             185      Delivered
# 8242  3263410000999932634           1             130      Delivered
# 1739  2120410000999921204           1             163    Not Shipped
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 9450  2021-09-07       Healthcare         Abdul                  24
# ...

# %% [markdown]
# ## df.drop()
# ##### The . drop() method is a built-in function in Pandas that allows you to remove one or more rows or columns from a DataFrame. It returns a new DataFrame with the specified rows or columns removed and does not modify the original DataFrame in place, unless you set the "inplace" parameter to True.

# %%
df2 = df.drop(2,axis=0)
df2
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 0     2951110000999929511        92             238  Not Delivered
# 1     2181910000999921819        61             136  Not Delivered
# 3     1112610000999911126        33             133    Not Shipped
# 4     1548310000999915483        13             189  Not Delivered
# 5     4934810000999949348        51             204  Not Delivered
# ...                   ...       ...             ...            ...
# 9994  2301610000999923016        75             201  Not Delivered
# 9995  1847410000999918474        37             135        Shipped
# 9996  2385710000999923857        81             207      Delivered
# 9997  2281610000999922816        18             117        Shipped
# 9998  1468010000999914680        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0     2021-08-08       Healthcare         Pablo                  21
# ...

# %% [markdown]
# ## df.corr()
# ##### The corr() aggregate function returns a coefficient of correlation between two numbers.

# %%
 df.corr()
# Out:
#                       OrderID  Quantity  UnitPrice(USD)  Shipping_Cost(USD)  \
# OrderID              1.000000  0.008028        0.000866           -0.002899
# Quantity             0.008028  1.000000       -0.007948           -0.008935
# UnitPrice(USD)       0.000866 -0.007948        1.000000           -0.002698
# Shipping_Cost(USD)  -0.002899 -0.008935       -0.002698            1.000000
# Delivery_Time(Days) -0.017483 -0.003023       -0.013938           -0.004026
# OrderCode            0.005441 -0.002827        0.015882            0.008126
#
#                      Delivery_Time(Days)  OrderCode
# OrderID                        -0.017483   0.005441
# Quantity                       -0.003023  -0.002827
# UnitPrice(USD)                 -0.013938   0.015882
# Shipping_Cost(USD)             -0.004026   0.008126
# Delivery_Time(Days)             1.000000   0.008851
# OrderCode                       0.008851   1.000000
